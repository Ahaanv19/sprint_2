# %% [markdown]
# ---
# layout: post
# title: Assignment Statements and Input
# permalink: /input
# ---

# %% [markdown]
# ## Assignment Statements and Input

# %% [markdown]
# ### Assignment Statements
#
# ```
#
#
# ```

# %% [markdown]
# ### Input
